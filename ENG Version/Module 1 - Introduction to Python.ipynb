# %% [markdown]
# # 1. Data Types

# %% [markdown]
# Simply **DataTypes** is a way to represent values in Python. The types listed below are the most commonly used data types in Python.
#
# - **int (represents numbers)**
# - **float (represents decimals)**
# - **str (represents text)**
# - **bool (represents bool values)**
# - **list**
# - **dict**
# - tuple
# - set
# - complex (not used very often)
# - None (to represent an absence of value)

# %% [markdown]
# ## 1.1 Numbers

# %% [markdown]
# There are **3** data types are available:
#
# - int (stores integers of unlimited size)
# - float (stores floating-point real-number values)
# - complex (stores complex numbers)

# %%
num = 100 #int  # declaring variable
print(type(num)) # <class 'int'>

num = 99.99
print(type(num)) # <class 'float>

num2 = 10.8

expression1 = num * 10
print(type(expression1)) # <class 'int'>

expression2 = num + num2
print(type(expression2)) # <class 'float'>
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
10 + 19.8 = 29.8

# %% [markdown]
# ### Mathematical Functions

# %%
2.5 -> 3 # ceiling
2.4 -> 2 # floor 

-34 -> 34

34 -> 34

# %%
print(round(2.1)) # 2
print(round(5.9)) # 6
print(abs(-34)) #   34

# %% [markdown]
# ### Mathematical Operators
# In Python, you can demonstrate calculator operations on numbers

# %%
x = 10 # int

print(x+2) # Sum #12 # int
print(x-2) # Diff # 8 # int
print(x*2) # Multiplication  #20 #int
print(x/2) # Division # 5 #int # will result with remainders

print(x**2) # Exponential 
print(x//2) # Divide (without remainder)
print(x%2) # Mod (Remainder)
# Out:
# 12
# 8
# 20
# 5.0
# 100
# 5
# 0

# %%
10//2.2
# Out:
# 4.0

# %% [markdown]
# ## 1.2 Değişkenler (Variables)

# %% [markdown]
# Variables store values. The following are the naming conventions in Python:
#
# - Variables must begin with a letter (preferably lowercase) or an underscore followed by numbers or an underscore
# - Snake case is the traditional way of writing variable with multiple words like user_name
# - They are case sensitive
# - Keywords should not be overwritten by keywords (Python keywords)

# %% [markdown]
# ## 1.3 Strings

# %%
st = "Lerjdnhdf1290204938430.,?=)(//^+/^'/('!('!(+'!+('^!(+("

# %%
name = 'Python' # implementing with single quote
name2 = "Python" # implementing with double quote



name3 = '''I can write comments on multiple lines.
Fethi
Tekyaygil
Python
Global AI Hub
            Because why not?''' # implementing multiline string with 3 quotes

print(type(name)) # <class 'str'>
print(type(name2)) # <class 'str'>
print(type(name3)) # <class 'str'>


print(name3)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# I can write comments on multiple lines.
# Fethi
# Tekyaygil
# Python
# Global AI Hub
#             Because why not?

# %% [markdown]
# ### String Concatenation

# %%
first_name = 'Fethi'
last_name = 'Tekyaygil'

name_surname = first_name + ' ' +last_name
print(name_surname)

# This method is deprecated
# print(first_name + ' ' + last_name) # Fethi Tekyaygil

""" -> 3 double quote
This comments is very long
Because I want it to be
Bla bla
something something
"""
# Out:
# Fethi Tekyaygil
# ' -> 3 double quote\nThis comments is very long\nBecause I want it to be\nBla bla\nsomething something\n'

# %%
FethiTekyaygil

# %% [markdown]
# ### Type Conversion

# %%
"15" * 10
# Out:
# '15151515151515151515'

# %%
user_entered_value = input("Please enter a number that will be multiplicated with 2: ")
print(type(user_entered_value))

print(user_entered_value * 2)
# Out:
# Please enter a number that will be multiplicated with 2: 15
# <class 'str'>
# 1515

# %%
user_entered_value = input("Please enter a number that will be multiplicated with 2: ")

user_entered_value_int = int(user_entered_value)

print(user_entered_value_int * 2)
# Out:
# Please enter a number that will be multiplicated with 2: 15
# 30

# %%
int()

# %%
type("Fethi")
# Out:
# str

# %%
user_entered_value = int(input("Please enter a number that will be multiplicated with 2: "))

print(user_entered_value * 2)
# Out:
# Please enter a number that will be multiplicated with 2: 15
# 30

# %%
int("Fethi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5deb6b0281fb> in <module>()
# ----> 1 int("Fethi")
#
# ValueError: invalid literal for int() with base 10: 'Fethi'

# %%
user_name = 'Fethi'
age = 25
print(user_name + age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-fe5323ff367a> in <module>()
#       1 user_name = 'Fethi'
#       2 age = 25
# ----> 3 print(user_name + age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
user_name = 'Fethi'
age = 25
print(user_name + str(age)) # Fethi25
print(type(str(age))) # <class 'str'>
# Out:
# Fethi25
# <class 'str'>

# %%
num_string = "7"

print(type(int(num_string)))
# Out:
# <class 'int'>

# %%
print(type("7"))
# Out:
# <class 'str'>

# %%
lucky_number = 7
lucky_number_stringified = str(7)
lucky_number_extracted = int(lucky_number_stringified)
print(lucky_number_extracted) # 7

# %% [markdown]
# ### Formatted String
#
# String formatting is a feature that allows us to dynamically update string contents. Suppose we have user information retrieved from a server and we want to display a custom message based on it. The first idea is to apply string formatting.

# %%
first_name = 'Fethi'
last_name = 'Tekyaygil'
welcome_message = "Welcome" + " " + first_name + " " + last_name

print(welcome_message) # Welcome Fethi Tekyaygil
# Out:
# Welcome Fethi Tekyaygil

# %%
first_name = 'Fethi'
last_name = 'Tekyaygil'
welcome_message = f"Welcome {first_name} {last_name}"

print(welcome_message) # Welcome Fethi Tekyaygil
# Out:
# Welcome Fethi Tekyaygil

# %% [markdown]
# ### String Indexes
#
# Strings in Python are simply an ordered collection of characters. So we can do a lot of great tricks with it. We can access the characters of a string, select a substring, reverse a string, and much more. It is also called string slicing.

# %%
name = "Fethi?*"
F e t h i ? *
0 1 2 3 4 5 6

4 - i

6 - *

10 - Error

# %%
language = 'python'
print(language[0])
print(language[5])
# Out:
# p
# n

# %%
language = 'python'
first_character = language[0] # indexing starts from 0
second_character = language[1]
print(first_character) # p
print(second_character) # y

# %%
 p   y  t  h  o  n
 0   1  2  3  4  5
-6  -5 -4 -3 -2 -1


+1 means take step to right

# %%
language[-4]
# Out:
# 't'

# %%
language[-2:-5:-1]
# Out:
# 'oht'

# %%
language[0:3]
# Out:
# 'pyt'

# %%
language[1:4]
# Out:
# 'yth'

# %%
language[1:5:2]
# Out:
# 'yh'

# %%
y h
1 3

# %%
# Strings can be manipulated easily with this syntax [start:stop:step-over] Slicing

range_1 = language[0:2] # here it starts from index 0 and ends at index 1
range_2 = language[0::1] # starts at 0, stops at end with step over 1 
range_3 = language[::2] # starts at 0, till end with step 2
range_4 = language[1:] # starts at index 1 till end of string
range_5 = language[-1] # selects last character
range_6 = language[-2] # second last character
reverse_string = language[::-1] # starts from end and reverses the string
reverse_string_2 = language[::-2] # reverses string and skips 1 character

print(range_1) # py
print(range_2) # python
print(range_3) # pto
print(range_4) # ython
print(range_5) # n
print(range_6) # o
print(reverse_string) # nohtyp
print(reverse_string_2) # nhy

# %% [markdown]
# ## 1.4 Logical Operators & Boolean
#
# Booleans stores only True or False values.

# %%
am_i_good_teacher = True
do_i_hate_python = False

# %%
print(type(am_i_good_teacher))
# Out:
# <class 'bool'>

# %%
num = 0
print(bool(num))
# Out:
# False

# %%
is_it_okay = True
id_dirty = False

# %%
print(10 > 9) # True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(True or False)
print(True and True)
print(not False)
# Out:
# True
# True
# True

# %%
name = 'Fethi'
surname = 'Tekyaygil'
print(name == surname)
# Out:
# False

# %% [markdown]
# ## 1.5 Lists
#
# Lists are an important data type. It is an organized collection of objects. It is also a data structure, meaning a container that organizes data in a certain way for different purposes. They are denoted by `[]`. They can be used to store the same or different types of data together.

# %%
User # you implemented complex type developer creates the data
name
surname
id
phone number
grades

# %%
favorite_languages = ['javascript', 'python', 'c#']
shopping_cart_items = ['pencil', 'tooth brush', 'cologne', 'eraser']
random_things = ['football', 123, True, 'developer', 777.9]

first_item = shopping_cart_items[0]
print(first_item) # 'pencil'
# Out:
# pencil

# %% [markdown]
# ###  List Slicing
#
# Similar to strings, lists can also be sliced. However, unlike strings, lists are mutable, which means their data can be changed.

# %%
soccer_stars = ['ronaldo', 'messi', 'ibrahimovic', 'zidane', 'beckham']
soccer_stars[0] = 'totti'
print(soccer_stars) # ['totti', 'messi','ibrahimovic','zidane','beckham']
# Out:
# ['totti', 'messi', 'ibrahimovic', 'zidane', 'beckham']

# %%
range = soccer_stars[0:3]
print(range) # ['totti', 'messi', 'ibrahimovic']
print(soccer_stars) # ['totti', 'messi','ibrahimovic','zidane','beckham']
# Out:
# ['totti', 'messi', 'ibrahimovic']
# ['totti', 'messi', 'ibrahimovic', 'zidane', 'beckham']

# %%
soccer_stars
# Out:
# ['totti', 'messi', 'ibrahimovic', 'zidane', 'beckham']

# %%
soccer_stars[:3]
# Out:
# ['totti', 'messi', 'ibrahimovic']

# %%
soccer_stars[1:]
# Out:
# ['messi', 'ibrahimovic', 'zidane', 'beckham']

# %%
soccer_stars[:]
# Out:
# ['totti', 'messi', 'ibrahimovic', 'zidane', 'beckham']

# %%
clone = soccer_stars[:] # listeyi kopyalar.
print(clone) # ['suarez', 'messi','ibrahimovic','zidane','beckham']
# Out:
# ['totti', 'messi', 'ibrahimovic', 'zidane', 'beckham']

# %%
soccer_stars[::-1]

# %%
reverse_order = soccer_stars[::-1] # listenin sırasını tersine çevirir
print(reverse_order) # ['beckham', 'zidane', 'ibrahimovic', 'messi', 'suarez']
# Out:
# ['beckham', 'zidane', 'ibrahimovic', 'messi', 'totti']

# %% [markdown]
# ### Adding element to the list (append, insert, extend)

# %%
# Append

scores = [44,48,55,89,34]
scores.append(100) # appends elements at the end of the string
print(scores) # [44, 48, 55, 89, 34, 100]
# Out:
# [44, 48, 55, 89, 34, 100]

# %%
# Insert

scores.insert(0, 34) # Inserts 34 to index 0
scores.insert(2, 54) # Inserts 44 to index 2
print(scores) # [34, 44, 54, 48, 55, 89, 34, 100]
# Out:
# [34, 44, 54, 48, 55, 89, 34, 100]

# %%
scores
# Out:
# [34, 44, 54, 48, 55, 89, 34, 100]

# %%
#scores.append([23, 45, 98, 77])

# %%
# Extend

scores.extend([23, 45, 98, 77]) # Adds a list's element at the end of another list
print(scores) # [34, 44, 54, 48, 55, 89, 34, 100, 23, 45, 98, 77]
# Out:
# [34, 44, 54, 48, 55, 89, 34, 100, 23, 45, 98, 77]

# %%
scores.extend([12,10])
print(scores) # [34, 44, 44, 48, 55, 89, 34, 100, 23, 12, 10]

# %% [markdown]
# ### removing an element to the list (pop, remove, clear)

# %%
# Pop

languages = ['C', 'C#', 'C++']
print(languages.pop())
print(languages) # ['C', 'C#']
# Out:
# C++
# ['C', 'C#']

# %%
# Remove

languages.remove('C')
print(languages) # ['C#']
# Out:
# ['C#']

# %%
# Clear
languages = ['C', 'C#', 'C++']
languages.clear()
print(languages) # []
# Out:
# []

# %% [markdown]
# ### Gather indexes and count (index, count)

# %%
alphabets = ['a', 'b', 'c', 'b', 'a']

# %%
print(alphabets.index('a')) # 0 (Returns index of 'a')
# Out:
# 0

# %%
print(alphabets.count('b')) # 1 (Return occurences of 'b')
# Out:
# 2

# %% [markdown]
# ### Sorting, reversing and copying

# %%
# Sort

numbers = [1,4,6,3,2,5]
numbers.sort() # Sorts the list items in place and returns nothing
print(numbers) # [1, 2, 3, 4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Sorted
# Get as a new list
numbers = [1,4,6,3,2,5]

sorted_numbers = sorted(numbers) # note - this is not a method
print(sorted_numbers) # [1, 2, 3, 4, 5, 6]
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 4, 6, 3, 2, 5]

# %%
# Reverse

numbers.reverse() # Listeyi tersine çevirir
print(numbers) # [6, 5, 4, 3, 2, 1]
# Out:
# [5, 2, 3, 6, 4, 1]

# %%
# Copy

numbers_clone = numbers.copy() # numbers[:] does the same thing
print(numbers_clone) # [6, 5, 4, 3, 2, 1]
# Out:
# [5, 2, 3, 6, 4, 1]

# %% [markdown]
# ## 1.5 Dictionaries

# %%
user = {'name': 'Fethi', 'age': 25, 'married': False}

# %%
print(user['name'])    # Fethi
print(user['married']) # False
# Out:
# Fethi
# False

# %% [markdown]
# ### Dictionary Keys
#
# "dict" keys can be of any literal data type. Also, keys must be unique. If a dictionary has more than one identical key, the values are overridden. This is also called collision.

# %%
user = {'name': 'Fethi', 'age': 25, 'married': False, "name":"Taha"}
user
# Out:
# {'age': 25, 'married': False, 'name': 'Taha'}

# %%
abstract = {
 'first': 123,
 True: 'hello',
 777: [1,3,4,5]
}

# %%
abstract[777]
# Out:
# [1, 3, 4, 5]

# %%
print(abstract['first']) # 123
print(abstract[True]) # 'hello
print(abstract[777]) # [1,3,4,5]

# %%
sample = {
    'username': 'Taha',
    'username': 'Fethi'
}

# %%
print(sample['username'])

# %% [markdown]
# ### Dictionary Methods

# %%
user = {'name': 'Fethi', 'age': 25, 'country': 'Turkey'}

# %%
user.keys()
# Out:
# dict_keys(['name', 'age', 'country'])

# %%
user.values()
# Out:
# dict_values(['Fethi', 25, 'Turkey'])

# %%
user.items()
# Out:
# dict_items([('name', 'Fethi'), ('age', 25), ('country', 'Turkey')])

# %%
print('name' in user.keys()) # True
print('gender' in user.keys()) # False
print('Fethi' in user.values()) # True
# Out:
# True
# False
# True

# %% [markdown]
# ## Project: Calculating Body Mass Index
#
# Get 3 inputs from the user:
# 1. Name (take as string)
# 2. Weight (take as float)
# 3. Height (take as an integer in centimeters)
#
# Calculate the body mass index of the person using the entered height and weight inputs (BMI = weight / height^2) and round to the 2nd digit after the comma (You should use the entered height in centimeters, in meters when calculating)
#
# If you test your body mass index calculation code using weight = 75, height = 1.85, you should get "21.91"
#
# Create a dictionary for the person entered: Key = name, value = body mass index
#
# Repeat 3 times up to this point and you'll get a 3-element list of dictionaries
#
# Finally, print the names and body mass index data of the 3 people on the list one after the other.
#
# Example Output:
# * Furkan 24.8
# * Berfin 19.16
# * Joseph 21.91

# %%
people = {}

name = input("Please enter your name: ")
weight = int(input("Please enter your mass: "))
height = float(input("Please enter your height: "))

bmi = round(weight / (height ** 2), 2)
people[name] = bmi


name = input("Please enter your name: ")
weight = int(input("Please enter your mass: "))
height = float(input("Please enter your height: "))

bmi = round(weight / (height ** 2), 2)
people[name] = bmi


for key, value in people.items():
  print(f"{key} {value}")
# Out:
# Please enter your name: Fethi
# Please enter your mass: 80
# Please enter your height: 1.80
# Please enter your name: Taha
# Please enter your mass: 70
# Please enter your height: 1.76
# Fethi 24.69
# Taha 22.6

# %%
people = []

name = input("Please enter your name: ")
mass = float(input("Mass: "))
height = int(input("Height (cm): ")) / 100
vki = round(mass/((height)**2), 2)
person = {name:vki}
people.append(person)


name = input("Please enter your name: ")
mass = float(input("Mass: "))
height = int(input("Height (cm): ")) / 100
vki = round(mass/((height)**2), 2)
person = {name:vki}
people.append(person)


name = input("Please enter your name: ")
mass = float(input("Mass: "))
height = int(input("Height (cm): ")) / 100
vki = round(mass/((height)**2), 2)
person = {name:vki}
people.append(person)

print(list(people[0].keys())[0],list(people[0].values())[0])
print(list(people[1].keys())[0],list(people[1].values())[0])
print(list(people[2].keys())[0],list(people[2].values())[0])
